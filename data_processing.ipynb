# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_and_preprocess_data(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    return pd.DataFrame(data)


Grocery_and_Gourmet_Food_path = "/Users/kapilwanaskar/Downloads/AWS_BEDROCK/recommendation_system/dataset/meta_Grocery_and_Gourmet_Food.jsonl"
df = load_and_preprocess_data(Grocery_and_Gourmet_Food_path)

# download df to csv
df.to_csv('Grocery_and_Gourmet_Food.csv', index=False)

# print list of columns names
print(df.columns)

# display first 5 rows of the data
display(df.head())
# Out:
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together', 'subtitle', 'author'],
#       dtype='object')
#   main_category                                              title  \
# 0       Grocery                             Dark Roast Pure Coffee
# 1       Grocery  PICARAS Galletas Peruanas Bañadas en Chocolate...
# 2       Grocery  Chipped Beef and Gravy By Patterson's - Great ...
# 3       Grocery  Asher's Sugar Free Milk Chocolate Cordial Cher...
# 4       Grocery              Messmer Peppermint 25 bags (6er pack)
#
#    average_rating  rating_number  \
# 0             4.7              9
# 1             4.5             12
# 2             3.2              5
# 3             5.0              6
# 4             3.5              5
#
#                                             features  \
# ...

# %%
# number of null values in each column
print(df.isnull().sum())
# Out:
# main_category        7960
# title                   0
# average_rating          0
# rating_number           0
# features                0
# description             0
# price              378955
# images                  0
# videos                  0
# store               17280
# categories              0
# details                 0
# parent_asin             0
# bought_together    603274
# subtitle           603254
# author             603257
# dtype: int64

# %%
# number of rows and columns in df data
print(df.shape)
# Out:
# (603274, 16)

# %%
# download df to csv
df.to_csv('Grocery_and_Gourmet_Food.csv', index=False)

# %%
# download top 10000 rows to csv
df.head(1000).to_csv('Grocery_and_Gourmet_Food_1000.csv', index=False)

# %%
# filter and keep features = [main_category,title, description]
df_filtered = df[['main_category', 'title', 'description']]

# download top 1000 rows to csv
df_filtered.head(1000).to_csv('Grocery_and_Gourmet_Food_filtered_1000.csv', index=False)
